# %%
import pandas as pd
import numpy as np

# %%
cluster_labels_filepath = 'data_gen/cluster_labels.npy'
cluster_labels_array = np.load(cluster_labels_filepath)

# %%
pd.DataFrame(cluster_labels_array)
# Out:
#        0
# 0      4
# 1      7
# 2      8
# 3      8
# 4      8
# ...   ..
# 2616   0
# 2617  10
# 2618   8
# 2619   6
# 2620   7
#
# [2621 rows x 1 columns]
